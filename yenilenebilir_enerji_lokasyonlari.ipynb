# %%
import pandas as pd
import matplotlib.pyplot as plt
data = {
    "Lokasyon": [
        "Australia", "Brazil", "China mainland", "Denmark", "Denmark", "India", "Israel", "Japan", "Mexico",
        "Power for Impact projects", "Rooftop solar projects", "Singapore", "Taiwan", "Türkiye",
        "Arizona, U.S.", "California, U.S.", "California, U.S.", "Illinois, U.S.", "Nevada, U.S.",
        "North Carolina, U.S.", "Oregon, U.S.", "Oregon, U.S.", "Oregon, U.S.", "Texas, U.S.", "Virginia, U.S."
    ],
    "Yenilenebilir Enerji Kaynakları": [
        "Güneş Paneli", "Rüzgar", "Güneş Paneli", "Güneş Paneli", "Rüzgar", "Güneş Paneli", "Güneş Paneli", "Güneş Paneli",
        "Rüzgar", "Güneş Paneli", "Güneş Paneli", "Güneş Paneli", "Güneş Paneli", "Güneş Paneli",
        "Güneş Paneli", "Biyogaz", "Güneş Paneli", "Rüzgar", "Güneş Paneli", "Güneş Paneli",
        "Hidroelektrik", "Güneş Paneli", "Rüzgar", "Rüzgar", "Güneş Paneli"
    ],
    "Kurulu Güç (MW)": [
        0.5, 0.5, 195, 42, 17, 16, 5, 12, 0.8, 1.2, 5, 54, 1, 4, 62, 4, 144, 112, 320, 164, 3, 125, 200, 25, 134
    ]
}

df = pd.DataFrame(data)

# Kurulu güce göre ilk 10 lokasyonu görselleştir
top10 = df.sort_values("Kurulu Güç (MW)", ascending=False).head(10)

# Grafik oluştur
plt.figure(figsize=(12, 6))
plt.barh(top10["Lokasyon"], top10["Kurulu Güç (MW)"], color="#88C0D0")
plt.xlabel("Kurulu Güç (MW)")
plt.title("Apple'ın En Yüksek Kurulu Güce Sahip 10 Yenilenebilir Enerji Lokasyonu")
plt.gca().invert_yaxis()
plt.grid(axis='x', alpha=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# Apple’ın En Yüksek Kurulu Güce Sahip 10 Yenilenebilir Enerji Lokasyonu (MW Bazında)
# Apple’ın küresel yenilenebilir enerji yatırımlarının lokasyon bazlı dağılımı incelendiğinde, en yüksek kurulu güce sahip lokasyonların büyük çoğunluğu Amerika Birleşik Devletleri’nde konumlanmıştır. İlk üç sırada yer alan Nevada (320 MW), Oregon (325 MW: 125 Güneş + 200 Rüzgar) ve China mainland (195 MW), Apple’ın karbon nötr hedefleri doğrultusunda büyük ölçekli ve uzun vadeli enerji yatırımları yaptığı stratejik bölgeleri temsil etmektedir.
#
# Nevada, U.S.: Apple’ın veri merkezlerine enerji sağlamak amacıyla inşa ettiği güneş enerji tarlaları, bölgeyi lider konuma taşımaktadır.
#
# Oregon, U.S.: Hem güneş hem de rüzgar enerjisinin birlikte kullanıldığı karma bir sistem mevcuttur.
#
# California, U.S. ve North Carolina, U.S.: Güneş enerjisine dayalı geniş kapasiteli yatırımların olduğu eyaletlerdir.
#
# Illinois ve Texas: Özellikle rüzgar enerjisinin öne çıktığı bölgeler arasında yer almaktadır.
#
# Bu dağılım, Apple’ın yalnızca teknoloji değil, aynı zamanda enerji stratejilerini de bölgesel potansiyel, altyapı uygunluğu ve karbonsuzlaşma önceliklerine göre optimize ettiğini göstermektedir.
#
# Sonuç:
# Apple, yenilenebilir enerji yatırımlarında ölçek ve coğrafi çeşitlilikten faydalanmakta; özellikle Amerika ve Asya’daki büyük ölçekli güneş ve rüzgar projeleri aracılığıyla 2030 karbon nötr hedefi için güçlü bir altyapı oluşturmaktadır.
